# %%
import pandas as pd
import numpy as np

# %%
### Loading the data
df = pd.read_csv("owid-covid-data.csv")
df.head()

### We also want to make sure we fix the date column.
df["date"] = pd.to_datetime(df["date"])

df.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
#Based on the Machine learning we divied the dataset in 3 groupes depending on the number of case :
# low, medium and High
# we randomly selectec 6 countries as below 
# Low : Cyprus, Dominican Republic
# med : jersey, Gambia
# high : Palestine, Oman
### Selection the continent we want to Analyse (America is divided in North America and South America)
# ### Selection the continent we want to Analyse (America is divided in North America and South America)

countries_hml = "Cyprus", "Dominican Republic", "jersey", "Gambia", "Palestine", "Oman"
countries_hml = df[countries_df['location'].isin(countries_hml)]
countries_hml.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17400/769317596.py in <module>
#       7 ### Selection the continent we want to Analyse (America is divided in North America and South America)
#       8 countries_hml = "Cyprus", "Dominican Republic", "jersey", "Gambia", "Palestine", "Oman"
# ----> 9 countries_hml = df[df['location'].isin("location")]
#      10 countries_hml.head()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\series.py in isin(self, values)
#    5023         dtype: bool
#    5024         """
# -> 5025         result = algorithms.isin(self._values, values)
#    5026         return self._constructor(result, index=self.index).__finalize__(
#    5027             self, method="isin"
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\algorithms.py in isin(comps, values)
#     458     if not is_list_like(values):
# ...

# %%
df.to_csv("test1.csv", index = False)

# %%
# Drop all the empty cells
df=df[df!=0].dropna()

df
# Out:
# Empty DataFrame
# Columns: [continent, location, date, new_cases, new_deaths, total_cases, total_deaths, reproduction_rate, hosp_patients, new_tests, positive_rate, new_vaccinations, population, median_age, hospital_beds_per_thousand]
# Index: []

# %%
# determine the countries that have the most covid 19 cases
Sum_new_cases_per_countries = df.groupby(["location"]).sum()["new_cases"]
Mean_new_cases_per_countries = df.groupby(["location"]).mean()["new_cases"]
Sum_new_death_per_countries = df.groupby(["location"]).sum()["new_deaths"]
Mean_new_death_per_countries = df.groupby(["location"]).mean()["new_deaths"]

# %%
# Create a new Dataframe
figures_by_countries = pd.DataFrame({
               "Sum_new_cases_per_countries": Sum_new_cases_per_countries,
               "Mean_new_cases_per_countries": Mean_new_cases_per_countries,
               "Sum_new_death_per_countries": Sum_new_death_per_countries,
               "Mean_new_death_per_countries": Mean_new_death_per_countries
               })
figures_by_countries
# Out:
#                 Sum_new_cases_per_countries  Mean_new_cases_per_countries  \
# location
# Australia                          178282.0                   2025.931818
# Austria                            863660.0                   2750.509554
# Belgium                           1486676.0                   4890.381579
# Bulgaria                           160552.0                   1029.179487
# Canada                            1762708.0                   4602.370757
# Croatia                            129097.0                   1016.511811
# Cyprus                              19276.0                    458.952381
# Czechia                           1805312.0                   5437.686747
# Denmark                            344153.0                   1801.848168
# Estonia                            203378.0                    696.500000
# Finland                             17697.0                   5899.000000
# ...

# %%
# sort the df in an ascending order to determine the 5 contries with the most deaths
figures_by_countries.sort_values(by=['Sum_new_death_per_countries'], inplace=True)
figures_by_countries.tail()
# Out:
#                 Sum_new_cases_per_countries  Mean_new_cases_per_countries  \
# location
# Poland                            1646481.0                   7484.004545
# France                            8106733.0                  21969.466125
# Italy                             4348414.0                  11689.284946
# United Kingdom                    9696124.0                  27467.773371
# United States                    39806283.0                 103125.085492
#
#                 Sum_new_death_per_countries  Mean_new_death_per_countries
# location
# Poland                              40325.0                    183.295455
# France                              61385.0                    166.355014
# Italy                               65861.0                    177.045699
# United Kingdom                      67030.0                    189.886686
# United States                      524510.0                   1358.834197

# %%
# sort the df in an ascending order to determine the 5 contries with the most cases
figures_by_countries.sort_values(by=['Sum_new_cases_per_countries'], inplace=True)
figures_by_countries.tail()
# Out:
#                 Sum_new_cases_per_countries  Mean_new_cases_per_countries  \
# location
# Malaysia                          2475270.0                   7908.210863
# Italy                             4348414.0                  11689.284946
# France                            8106733.0                  21969.466125
# United Kingdom                    9696124.0                  27467.773371
# United States                    39806283.0                 103125.085492
#
#                 Sum_new_death_per_countries  Mean_new_death_per_countries
# location
# Malaysia                            30467.0                     97.338658
# Italy                               65861.0                    177.045699
# France                              61385.0                    166.355014
# United Kingdom                      67030.0                    189.886686
# United States                      524510.0                   1358.834197

# %%
# sort the df in an ascending order to determine the 5 contries with less deaths
figures_by_countries.sort_values(by=['Sum_new_death_per_countries'], inplace=True)
figures_by_countries.head()
# Out:
#             Sum_new_cases_per_countries  Mean_new_cases_per_countries  \
# location
# Finland                         17697.0                   5899.000000
# Cyprus                          19276.0                    458.952381
# Malta                           14856.0                    124.840336
# Luxembourg                      32548.0                    271.233333
# Denmark                        344153.0                   1801.848168
#
#             Sum_new_death_per_countries  Mean_new_death_per_countries
# location
# Finland                            29.0                      9.666667
# Cyprus                            105.0                      2.500000
# Malta                             224.0                      1.882353
# Luxembourg                        298.0                      2.483333
# Denmark                           711.0                      3.722513

# %%
# sort the df in an ascending order to determine the 5 contries with the most cases
figures_by_countries.sort_values(by=['Sum_new_cases_per_countries'], inplace=True)
figures_by_countries.tail()
# Out:
#                 Sum_new_cases_per_countries  Mean_new_cases_per_countries  \
# location
# Malaysia                          2475270.0                   7908.210863
# Italy                             4348414.0                  11689.284946
# France                            8106733.0                  21969.466125
# United Kingdom                    9696124.0                  27467.773371
# United States                    39806283.0                 103125.085492
#
#                 Sum_new_death_per_countries  Mean_new_death_per_countries
# location
# Malaysia                            30467.0                     97.338658
# Italy                               65861.0                    177.045699
# France                              61385.0                    166.355014
# United Kingdom                      67030.0                    189.886686
# United States                      524510.0                   1358.834197
